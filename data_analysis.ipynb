# %%
# -*- coding: utf-8 -*-
# @Date    : 2020-07-29 22:00:00
# @Author  : Henry Pham


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
## import dataset

# Read the first xlsx file
county_df = pd.read_excel('2020-2022-county-level-totals.xlsx')

# Read the second xlsx file
state_df = pd.read_excel('2020-2022-state-level-totals.xlsx')
county_df

county_df.to_csv('county_data.csv', index=False)

# %%
state_df
# Out:
#                    state  Total reported hate acts  Verbal harassment  \
# 0                Arizona                       112                 72
# 1             California                      4117               2992
# 2               Colorado                       118                 89
# 3   District of Columbia                       150                122
# 4                Florida                       217                156
# 5                Georgia                       140                 96
# 6               Illinois                       352                257
# 7               Maryland                       175                115
# 8          Massachusetts                       349                270
# 9               Michigan                       101                 71
# 10             Minnesota                       130                 94
# 11            New Jersey                       215                169
# ...

# %%
county_df
# Out:
#            county          state  total reported hate acts  Verbal harassment  \
# 0         Alameda     California                       494                357
# 1    Contra Costa     California                       104                 70
# 2            Cook       Illinois                       253                185
# 3          Harris          Texas                       105                 74
# 4            King     Washington                       348                233
# 5           Kings       New York                       382                272
# 6     Los Angeles     California                      1032                791
# 7       Middlesex  Massachusetts                       120                 90
# 8        New York       New York                       853                643
# 9          Orange     California                       278                196
# 10   Philadelphia   Pennsylvania                       117                 91
# ...

# %%
#perform data analysis about
